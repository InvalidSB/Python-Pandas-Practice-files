# %%
import pandas as pd

# %%
df = pd.read_csv('./data/survey_results_public.csv',index_col="ResponseId")

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df.shape
# Out:
# (83439, 47)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83439 entries, 1 to 83439
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    83439 non-null  object
#  1   Employment                    83323 non-null  object
#  2   Country                       83439 non-null  object
#  3   US_State                      14920 non-null  object
#  4   UK_Country                    4418 non-null   object
#  5   EdLevel                       83126 non-null  object
#  6   Age1stCode                    83243 non-null  object
#  7   LearnCode                     82963 non-null  object
#  8   YearsCode                     81641 non-null  object
#  9   YearsCodePro                  61216 non-null  object
#  10  DevType                       66484 non-null  object
#  11  OrgSize                       60726 non-null  object
# ...

# %%
pd.set_option("display.max_column",45)
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df.head(5)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# ...

# %%
schema_df = pd.read_csv('./data/survey_results_schema.csv',index_col="qname")

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# ...

# %%
schema_df.shape
# Out:
# (48, 5)

# %%
df["Country"]
# Out:
# ResponseId
# 1                                                 Slovakia
# 2                                              Netherlands
# 3                                       Russian Federation
# 4                                                  Austria
# 5        United Kingdom of Great Britain and Northern I...
#                                ...
# 83435                             United States of America
# 83436                                                Benin
# 83437                             United States of America
# 83438                                               Canada
# 83439                                               Brazil
# Name: Country, Length: 83439, dtype: object

# %%
people={
    'fname':["sujan","santosh","shashank"],
    "lname":["bhattarai","acharya","dhungel"],
    "email":["suj@gmail.com","san@gmail.com","shas@gmail.com"]
}

# %%
people
# Out:
# {'fname': ['sujan', 'santosh', 'shashank'],
#  'lname': ['bhattarai', 'acharya', 'dhungel'],
#  'email': ['suj@gmail.com', 'san@gmail.com', 'shas@gmail.com']}

# %%
df1 = pd.DataFrame(people)
df1
# Out:
#       fname      lname           email
# 0     sujan  bhattarai   suj@gmail.com
# 1   santosh    acharya   san@gmail.com
# 2  shashank    dhungel  shas@gmail.com

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df1["email"])
# Out:
# pandas.core.series.Series

# %%
df1.fname
# Out:
# 0       sujan
# 1     santosh
# 2    shashank
# Name: fname, dtype: object

# %%
df1.columns
# Out:
# Index(['fname', 'lname', 'email'], dtype='object')

# %%
df1.iloc[[0,1],2]
# Out:
# 0    suj@gmail.com
# 1    san@gmail.com
# Name: email, dtype: object

# %%
df1.loc[[0,1],['email','fname']]
# Out:
#            email    fname
# 0  suj@gmail.com    sujan
# 1  san@gmail.com  santosh

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df.shape
# Out:
# (83439, 47)

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# ...

# %%
df.Trans
# Out:
# ResponseId
# 1        No
# 2        No
# 3        No
# 4        No
# 5        No
#          ..
# 83435    No
# 83436    No
# 83437    No
# 83438    No
# 83439    No
# Name: Trans, Length: 83439, dtype: object

# %%
df['Trans'].value_counts()
# Out:
# No                        77275
# Prefer not to say          1764
# Yes                        1035
# Or, in your own words:      604
# Name: Trans, dtype: int64

# %%
df.Trans
# Out:
# ResponseId
# 1        No
# 2        No
# 3        No
# 4        No
# 5        No
#          ..
# 83435    No
# 83436    No
# 83437    No
# 83438    No
# 83439    No
# Name: Trans, Length: 83439, dtype: object

# %%
df.iloc[0]
# Out:
# MainBranch                                         I am a developer by profession
# Employment                      Independent contractor, freelancer, or self-em...
# Country                                                                  Slovakia
# US_State                                                                      NaN
# UK_Country                                                                    NaN
# EdLevel                         Secondary school (e.g. American high school, G...
# Age1stCode                                                          18 - 24 years
# LearnCode                       Coding Bootcamp;Other online resources (ex: vi...
# YearsCode                                                                     NaN
# YearsCodePro                                                                  NaN
# DevType                                                         Developer, mobile
# ...

# %%
df.loc[0,'Trans']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-66b996a64bd5> in <module>
# ----> 1 df.loc[0,'Trans']
#
# ...

# %%
df.loc[[0,1,2],"Trans"]

# %%
df.iloc[0:3,2]#iloc le chai 3-1 garxa,index value linchha

# %%
df.loc[0:3,"Employment"]#iloc le chai 3-0 garxa,string value linchha

# %%
df.Employment

# %%
df.loc[0:2,"Employment":"EdLevel"]

# %% [markdown]
# ## ------------------Index--------------------

# %%
df.tail() #id haru nai index hun...row ko

# %%
df1['email']

# %%
df1.set_index("email", inplace=True) #email is the unique value of the row

# %%
df1

# %%
df1.index

# %%
df1.iloc[1]

# %%
df1.iloc[0] #index ko var ma herna chai iloc use garne

# %%
df1.iloc[0]

# %%
#if hai puranai state ma back jana chahanchhau vane 
df1.reset_index(inplace=True)
df1

# %%
schema_df

# %%
schema_df.loc['LearnCode']

# %%
schema_df.sort_index() #ascending=False

# %%
schema_df

# %% [markdown]
# ##  -----------------FIltering----------------

# %%
filt= (df1["lname"] =="bhattarai") | (df1["fname"] =="shashank") #& is also used threre
#df1[filt] #or 


df1.loc[filt]

# %%
df1.loc[filt,"email"]

# %%
df1.loc[~filt,"email"]

# %%
# df
filtby =(df['CompTotal'] >200000 )

df.loc[filtby,["Country","Employment","OrgSize"]]

# %%
countries = ["India"]
country_filt =df['Country'].isin(countries)
df.loc[country_filt,["Employment",'YearsCode']]

# %%
filtlww=(df['LanguageHaveWorkedWith'].str.contains('JavaScript',na=False))
df.loc[filtlww,["Employment",'YearsCode']]

# %%
filtlww

# %% [markdown]
# ## Updating data in row and column---------------------

# %%
df1

# %%
df1.columns

# %%
df1.columns =["first_name","last_name","email"]

# %%
df1

# %%
df1.columns = [x.upper() for x in df1.columns]
df1

# %%
df1.EMAIL

# %%
df1.columns =df1.columns.str.replace('_',' ')
df1

# %%
df1.columns=df1.columns.str.replace(" ","_")
df1

# %%
df1.rename(columns={"FIRST_NAME":"fname","LAST_NAME":"lname"},inplace=True)

# %%
df1

# %%
df1.loc[2] =["karls","dhugs","karls@gmail.com"]
df1

# %%
df1.loc[0,'lname']='sharma'
df1

# %%
filtval=(df1['EMAIL']== "san@gmail.com")
# df1[filtval]['fname']="Santa"
df1[filtval].fname

# df1

# %%
filtval=(df1['EMAIL']== "san@gmail.com")
df1.loc[filtval,'fname']="Santa"
df1

# %%
df1['EMAIL'].str.upper()

# %%
df1['fname'].apply(len)

# %%
df1['EMAIL']=df1["EMAIL"].apply(lambda x: x.lower())
df1

# %%
df1.rename(columns={"EMAIL":"email"},inplace=True)
df1

# %%
df1.apply(len,axis="columns")

# %%
len(df1['email'])

# %%
df1.apply(lambda x: x.min())

# %%
df1.applymap(len)

# %%
df

# %%
df.rename (columns ={'CompTotal':"Salary"},inplace=True)

# %%
df.head()

# %%
df['SOAccount']=df['SOAccount'].map({"Yes":True,"No":False})

# %%
df

# %%
df['Gender'].map({"Man":"M","Woman":"F"})

# %%
filtgen=(df["Gender"]=="Woman")
df[filtgen].shape

# %% [markdown]
# ## add remove column row

# %%
df1['fname']+" "+df1['lname']

# %%
df1['fullname']=df1['fname']+" "+df1['lname']
df1

# %%
df1.drop(columns="fullname")

# %%
df1['fullname'].str.split(' ',expand=True)
# ('') yesle matra single letter ligxa

# %%
df1[['first','last']]=df1['fullname'].str.split(' ',expand=True)
df1

# %%
df1.append({"fname":"Jhon"},ignore_index=True)

# %%
df1.drop(index=0,inplace=True)

# %%
df1

# %%
df1.drop(columns=['fullname',"first","last"],inplace=True)

# %%
df1 =df1.append({"fname":"Sujan","lname":"Sharma","email":"suj@gmail.com"},ignore_index=True)

# %%
df1=df1.append({"fname":"praman","lname":"ghimire","email":"pram@gmail.com"},ignore_index=True)

# %%
df1

# %% [markdown]
# ## -------Sorting value----------

# %%
df1.sort_values(by="lname")

# %%
df1['lname'].apply(lambda x :x.lower())

# %%
df1

# %%
df.sort_values(by=["Country","Salary"], ascending=[True,False],inplace=True)
df

# %%
filtco=(df['Country']=="Nepal") & (df['Gender']=="Woman")
df.loc[filtco,['Salary',"Country"]]

# %%
df[['Country','Salary']]

# %%
df["Salary"].nlargest(5)

# %%
df.nlargest(10,'Salary')

# %%
df.nsmallest(3,"Salary")

# %% [markdown]
# ## -------Grouping and aggregating -------

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
country_grp=df.groupby("Country")
# country_grp.get_group("Nepal")
country_grp["OpSys"].value_counts().loc["Nepal"]
# Out:
# OpSys
# Windows                              149
# Linux-based                          121
# MacOS                                 52
# Windows Subsystem for Linux (WSL)     14
# Other (please specify):                1
# Name: OpSys, dtype: int64

# %%
filtctry= (df['Country']=='India')
# df.loc[filtctry,["Employment",'Currency',"Country","LanguageHaveWorkedWith"]]
df[filtctry]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 5233

# %%
country_grp["Salary"].agg(['mean','median'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-a848379f6960> in <module>
# ----> 1 country_grp["Salary"].agg(['mean','median'])
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1540                 stacklevel=2,
#    1541             )
# -> 1542         return super().__getitem__(key)
#    1543
#    1544     def _gotitem(self, key, ndim: int, subset=None):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/base.py in __getitem__(self, key)
#     278             # error: "SelectionMixin" has no attribute "obj"  [attr-defined]
#     279             if key not in self.obj:  # type: ignore[attr-defined]
# --> 280                 raise KeyError(f"Column not found: {key}")
#     281             return self._gotitem(key, ndim=1)
#     282
#
# KeyError: 'Column not found: Salary'

# %%
country_grp["Salary"].agg(['mean','median']).loc["India"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-f93a26f3c23f> in <module>
# ----> 1 country_grp["Salary"].agg(['mean','median']).loc["India"]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1540                 stacklevel=2,
#    1541             )
# -> 1542         return super().__getitem__(key)
#    1543
#    1544     def _gotitem(self, key, ndim: int, subset=None):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/base.py in __getitem__(self, key)
#     278             # error: "SelectionMixin" has no attribute "obj"  [attr-defined]
#     279             if key not in self.obj:  # type: ignore[attr-defined]
# --> 280                 raise KeyError(f"Column not found: {key}")
#     281             return self._gotitem(key, ndim=1)
#     282
#
# KeyError: 'Column not found: Salary'

# %%
filtctry= (df['Country']=='India')
# filtctry
# df.loc[filtctry,["Employment",'Currency',"Country","LanguageHaveWorkedWith"]]
df[filtctry]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 5233

# %%
country_grp["LanguageHaveWorkedWith"]

# %%
country_grp["LanguageHaveWorkedWith"].apply(lambda x:x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
country_res=df["Country"].value_counts()

country_res
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Dominica                                                    1
# Brunei Darussalam                                           1
# Tuvalu                                                      1
# Saint Vincent and the Grenadines                            1
# Saint Kitts and Nevis                                       1
# Name: Country, Length: 181, dtype: int64

# %%
ppwkp=country_grp["LanguageHaveWorkedWith"].apply(lambda x:x.str.contains('Python').sum())
ppwkp
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
pythondf= pd.concat([country_res,ppwkp],axis="columns", sort=False)
pythondf
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Dominica                                                  1
# Brunei Darussalam                                         1
# Tuvalu                                                    1
# Saint Vincent and the Grenadines                          1
# Saint Kitts and Nevis                                     1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7975
# India                                                                 5233
# ...

# %%
pythondf.rename(columns={"Country":"totaluser",'LanguageHaveWorkedWith':"knowpython"},inplace=True)

# %%
pythondf
# Out:
#                                                     totaluser  knowpython
# United States of America                                15288        7975
# India                                                   10511        5233
# Germany                                                  5625        2713
# United Kingdom of Great Britain and Northern Ir...       4475        2149
# Canada                                                   3012        1593
# ...                                                       ...         ...
# Dominica                                                    1           1
# Brunei Darussalam                                           1           1
# Tuvalu                                                      1           1
# Saint Vincent and the Grenadines                            1           0
# Saint Kitts and Nevis                                       1           0
#
# [181 rows x 2 columns]

# %%
pythondf['perpkp']=(pythondf['knowpython']/pythondf['totaluser']) *100
pythondf
# Out:
#                                                     totaluser  knowpython  \
# United States of America                                15288        7975
# India                                                   10511        5233
# Germany                                                  5625        2713
# United Kingdom of Great Britain and Northern Ir...       4475        2149
# Canada                                                   3012        1593
# ...                                                       ...         ...
# Dominica                                                    1           1
# Brunei Darussalam                                           1           1
# Tuvalu                                                      1           1
# Saint Vincent and the Grenadines                            1           0
# Saint Kitts and Nevis                                       1           0
#
#                                                         perpkp
# ...

# %%
pythondf.loc['Nepal']
# Out:
# totaluser     337.000000
# knowpython    178.000000
# perpkp         52.818991
# Name: Nepal, dtype: float64
